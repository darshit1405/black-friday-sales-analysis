# %% [markdown]
#     # Black Friday Sales Analysis - Multi Column Analysis
#
#     ## Objective
#     Combine multiple customer and product features to find deeper patterns in purchase behavior.
#
#     ## Steps Performed
#     - Combined multiple variables for grouped analysis
# - Compared spending across different segments
# - Visualized multi-feature relationships
# - Summarized cross-feature insights
#
#     ## Insights
#     - Multi-column analysis reveals patterns that single-variable analysis can miss
# - Combining demographic and product variables gives more useful business insights
# - This step improves decision-making depth

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('BlackFriday.csv')

del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(12,6),title='Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Gender',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
    sns.countplot(x='City_Category',hue='Age',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Age',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x='City_Category',hue='Gender',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Extra Visuals
# Additional visuals to summarize relationships across multiple variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df.select_dtypes(include='number').corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

if {'Age','Gender','Purchase'}.issubset(df.columns):
    plt.figure(figsize=(10,5))
    sns.barplot(x='Age', y='Purchase', hue='Gender', data=df, estimator=np.mean)
    plt.title("Average Purchase by Age and Gender")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Final Notebook Summary
# This notebook combines important variables to uncover deeper customer purchase patterns.
#
# ## Final Conclusion
# Black Friday customer behavior is influenced by multiple factors such as gender, age, marital status, occupation, and product category. A combined analysis gives more business value than looking at a single feature in isolation.
